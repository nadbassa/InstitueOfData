# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas.plotting 

from scipy import stats
plt.style.use("ggplot")

import warnings
warnings.filterwarnings("ignore")
from scipy import stats

# %%
df = pd.read_csv("C:/Users/nadun/Documents/InstitueOfData/DATA/breastcancerdata.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df = df.drop(['Unnamed: 32'],axis = 1)

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
dfm = df[df['diagnosis'] == 'M'].radius_mean
dfb = df[df['diagnosis'] == 'B'].radius_mean

# %%
plt.hist(dfm, bins = 30, fc= (1,0,0,0.5), label = 'Malignant')
plt.hist(dfb, bins = 30, fc= (0,1,0,0.5), label = 'Bening')
plt.xlabel('Radius Mean')
plt.ylabel('Frequency')
plt.title('M vs B Radius Mean')

plt.legend()
plt.show()

# %%
malignmax = dfm[0].max()
print("Most frequent malignant radius mean is: ",malignmax)
# Out:
# Most frequent malignant radius mean is:  17.99

# %%
data_bening = df[df["diagnosis"] == "B"]
data_malignant = df[df["diagnosis"] == "M"]
desc_bening = data_bening.radius_mean.describe()

# %%
desc_bening
# Out:
# count    357.000000
# mean      12.146524
# std        1.780512
# min        6.981000
# 25%       11.080000
# 50%       12.200000
# 75%       13.370000
# max       17.850000
# Name: radius_mean, dtype: float64

# %%
desc_bening[4] #25perc
# Out:
# 11.08

# %%
desc_bening[6] #75perc
# Out:
# 13.37

# %%
q1, q3 = np.percentile(data_bening.radius_mean, [25,75])

# %%
print(q1, q3)
# Out:
# 11.08 13.37

# %%
iqr =q3-q1

# %%
iqr
# Out:
# 2.289999999999999

# %%
whisker = 1.5 * iqr
whisker
# Out:
# 3.4349999999999987

# %%
lower_limit = q1 - whisker
upper_limit = q3 + whisker

# %%
print(lower_limit, upper_limit)
# Out:
# 7.645000000000001 16.805

# %%
plt.boxplot(df.radius_mean)
plt.show()

# %%
new_df = df[(df.radius_mean >= lower_limit) & (df.radius_mean <= upper_limit)]

# %%
new_df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 3    84348301         M        11.42         20.38           77.58      386.1
# 5      843786         M        12.45         15.70           82.57      477.1
# 7    84458202         M        13.71         20.83           90.20      577.9
# 8      844981         M        13.00         21.82           87.50      519.8
# 9    84501001         M        12.46         24.04           83.97      475.9
# ..        ...       ...          ...           ...             ...        ...
# 560    925292         B        14.05         27.15           91.38      600.4
# 561    925311         B        11.20         29.37           70.67      386.0
# 562    925622         M        15.22         30.62          103.40      716.9
# 566    926954         M        16.60         28.08          108.30      858.1
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.boxplot(new_df.radius_mean)
plt.show()

# %%
melted_data = pd.melt(df, id_vars = "diagnosis", value_vars = ['radius_mean', 'texture_mean'])

# %%
melted_data
# Out:
#      diagnosis      variable  value
# 0            M   radius_mean  17.99
# 1            M   radius_mean  20.57
# 2            M   radius_mean  19.69
# 3            M   radius_mean  11.42
# 4            M   radius_mean  20.29
# ...        ...           ...    ...
# 1133         M  texture_mean  22.39
# 1134         M  texture_mean  28.25
# 1135         M  texture_mean  28.08
# 1136         M  texture_mean  29.33
# 1137         B  texture_mean  24.54
#
# [1138 rows x 3 columns]

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x = "variable", y = "value", hue="diagnosis",data= melted_data)
plt.show()

# %%
data_bening.radius_mean.mean()
# Out:
# 12.14652380952381

# %%
data_bening.radius_mean.var()
# Out:
# 3.170221722043872

# %%
data_bening.radius_mean.std()
# Out:
# 1.7805116461410389

# %%
data_bening.radius_mean.describe()
# Out:
# count    357.000000
# mean      12.146524
# std        1.780512
# min        6.981000
# 25%       11.080000
# 50%       12.200000
# 75%       13.370000
# max       17.850000
# Name: radius_mean, dtype: float64

# %%
plt.hist(data_bening.radius_mean,bins=50,fc=(0,1,0,0.5),label='Bening',cumulative = True)
plt.xlabel('Bening Radius Mean')
plt.ylabel('Frequency')
plt.show()

# %%
mean_diff = data_malignant.radius_mean.mean() - data_bening.radius_mean.mean()
var_bening = data_bening.radius_mean.var()
var_malignant = data_malignant.radius_mean.var()
var_pooled = (len(data_bening)*var_bening +len(data_malignant)*var_malignant ) / float(len(data_bening)+ len(data_malignant))
effect_size = mean_diff/np.sqrt(var_pooled)
print("Effect size: ",effect_size)
# Out:
# Effect size:  2.2048585165041428

# %%
plt.figure(figsize = (15,10))
sns.jointplot(df.radius_mean,df.area_mean,kind="reg")
plt.show()

# %%
sns.pairplot(df[['radius_mean','area_mean']])

# %%
df.corr()
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot=True, fmt='.1f', vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
np.cov(df.radius_mean,df.area_mean)
print("Covariance between radius mean and area mean: ",df.radius_mean.cov(df.area_mean))
print("Covariance between radius mean and fractal dimension se: ",df.radius_mean.cov(df.fractal_dimension_se))
# Out:
# Covariance between radius mean and area mean:  1224.4834093464565
# Covariance between radius mean and fractal dimension se:  -0.00039762485764406277

# %%
p1 = df.loc[:,["area_mean","radius_mean"]].corr(method= "pearson")
p2 = df.radius_mean.cov(df.area_mean)/(df.radius_mean.std()*df.area_mean.std())
print('Pearson correlation: ')
print(p1)
print('Pearson correlation: ',p2)
# Out:
# Pearson correlation:
#              area_mean  radius_mean
# area_mean     1.000000     0.987357
# radius_mean   0.987357     1.000000
# Pearson correlation:  0.9873571700566128

# %%
ranked_data = df.rank()
spearman_corr = ranked_data.loc[:,["area_mean","radius_mean"]].corr(method= "pearson")
print("Spearman's correlation: ")
print(spearman_corr)
# Out:
# Spearman's correlation:
#              area_mean  radius_mean
# area_mean     1.000000     0.999602
# radius_mean   0.999602     1.000000

# %%
np.mean(df.radius_mean)
# Out:
# 14.127291739894563

# %%
np.median(df.radius_mean)
# Out:
# 13.37

# %%
statistic, p_value = stats.ttest_rel(df.radius_mean,df.area_mean)
print(p_value)
# Out:
# 1.5253492492559045e-184

# %%
mu, sigma = 110, 20  # mean and standard deviation
s = np.random.normal(mu, sigma, 100000)
print("mean: ", np.mean(s))
print("standart deviation: ", np.std(s))
# visualize with histogram
plt.figure(figsize = (10,7))
plt.hist(s, 100)
plt.ylabel("frequency")
plt.xlabel("IQ")
plt.title("Histogram of IQ")
plt.show()
# Out:
# mean:  109.95677281648182
# standart deviation:  19.997482540759353
